# %%
import requests

import numpy as np

from bokeh.plotting import figure, show, output_file, vplot
from bokeh.embed import components
import pandas as pd

# %%
symbol='APL'
api_url = 'https://www.quandl.com/api/v1/datasets/WIKI/%s.json?api_key=8L5MpAx2n-9x-tTp5jw4' %symbol
session = requests.Session()
session.mount('http://', requests.adapters.HTTPAdapter(max_retries=3))
raw_data = session.get(api_url)
        #r = requests.get(api_url)
data = raw_data.json()

# %%
data
# Out:
# {u'code': u'APL',
#  u'column_names': [u'Date',
#   u'Open',
#   u'High',
#   u'Low',
#   u'Close',
#   u'Volume',
#   u'Ex-Dividend',
#   u'Split Ratio',
#   u'Adj. Open',
#   u'Adj. High',
#   u'Adj. Low',
#   u'Adj. Close',
#   u'Adj. Volume'],
#  u'data': [[u'2015-03-04',
#    27.14,
#    27.16,
#    26.52,
#    26.63,
#    1598242.0,
#    0.0,
#    1.0,
#    27.14,
#    27.16,
#    26.52,
#    26.63,
#    1598242.0],
#   [u'2015-03-03',
#    27.14,
#    27.16,
#    26.52,
#    26.63,
#    1598242.0,
#    0.0,
#    1.0,
#    27.14,
#    27.16,
#    26.52,
#    26.63,
#    1598242.0],
#   [u'2015-03-02',
#    27.14,
#    27.16,
#    26.52,
#    26.63,
#    1598242.0,
#    0.0,
#    1.0,
#    27.14,
#    27.16,
#    26.52,
#    26.63,
#    1598242.0],
#   [u'2015-02-27',
#    26.85,
#    27.16,
#    26.52,
#    26.63,
#    1599515.0,
#    0.0,
#    1.0,
#    26.85,
#    27.16,
#    26.52,
#    26.63,
#    1599515.0],
#   [u'2015-02-26',
#    27.41,
#    27.5599,
#    26.72,
# ...

# %%
data= r.json()

# %%
data['column_names']
# Out:
# [u'Date',
#  u'Open',
#  u'High',
#  u'Low',
#  u'Close',
#  u'Volume',
#  u'Ex-Dividend',
#  u'Split Ratio',
#  u'Adj. Open',
#  u'Adj. High',
#  u'Adj. Low',
#  u'Adj. Close',
#  u'Adj. Volume']

# %%
df=pd.DataFrame(data['data'])

# %%
df.columns = data['column_names']

# %%
df.head()
# Out:
#          Date   Open     High    Low  Close     Volume  Ex-Dividend  \
# 0  2015-03-04  27.14  27.1600  26.52  26.63  1598242.0          0.0
# 1  2015-03-03  27.14  27.1600  26.52  26.63  1598242.0          0.0
# 2  2015-03-02  27.14  27.1600  26.52  26.63  1598242.0          0.0
# 3  2015-02-27  26.85  27.1600  26.52  26.63  1599515.0          0.0
# 4  2015-02-26  27.41  27.5599  26.72  27.08   542364.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0      27.14    27.1600     26.52       26.63    1598242.0
# 1          1.0      27.14    27.1600     26.52       26.63    1598242.0
# 2          1.0      27.14    27.1600     26.52       26.63    1598242.0
# 3          1.0      26.85    27.1600     26.52       26.63    1599515.0
# 4          1.0      27.41    27.5599     26.72       27.08     542364.0

# %%
def datetime(x):
    return np.array(x, dtype=np.datetime64)

p1 = figure(x_axis_type = "datetime")
p1.title = "Stock Closing Prices"
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'Date'
p1.yaxis.axis_label = 'Price'

p1.line(datetime(df['Date']), df['Open'], color='red', legend='open')
p1.line(datetime(df['Date']), df['Adj. Open'], color='green', legend='adj. open')
p1.line(datetime(df['Date']), df['Close'], color='black', legend='close')
p1.line(datetime(df['Date']), df['Adj. Close'], color='pink', legend='adj. close')
            
show(p1)

script, div = components(p1)  # open a browser
# Out:
# ERROR:/usr/local/lib/python2.7/site-packages/bokeh/core/validation/check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: da779b26-e55d-4c3b-b78e-4fbca766f77d

# %%
show(p1)
# Out:
# ERROR:/usr/local/lib/python2.7/site-packages/bokeh/core/validation/check.pyc:W-1001 (NO_DATA_RENDERERS): Plot has no data renderers: Figure, ViewModel:Plot, ref _id: da779b26-e55d-4c3b-b78e-4fbca766f77d

# %%
div
# Out:
# u'\n<div class="plotdiv" id="7dc10917-dab5-4190-967e-2f2e22f6ae31"></div>'

# %%
results='sjdkfl'

# %%
results=('234','jskdlf')

# %%
api_url = 'https://www.quandl.com/api/v1/datasets/WIKI/GOOG.json?api_key=8L5MpAx2n-9x-tTp5jw4' #% symbol
r = requests.get(api_url)
data = r.json()
df = pd.DataFrame(data['data'])
df.columns = data['column_names']
            
def datetime(x):
    return np.array(x, dtype=np.datetime64)

p1 = figure(x_axis_type = "datetime")
p1.title = "Stock Closing Prices"
p1.grid.grid_line_alpha=0.3
p1.xaxis.axis_label = 'Date'
p1.yaxis.axis_label = 'Price'

p1.line(datetime(df['Date']), df['Open'], color='#A6CEE3', legend=symbol)
script, div = components(p1)

# %%
script
# Out:
# '\n<script type="text/javascript">\n    Bokeh.$(function() {\n    var docs_json = {"798320a4-7349-4277-8225-bb4d54367473":{"roots":{"references":[{"attributes":{"overlay":{"id":"dbba2d24-4b9e-4cdd-b49c-149caa3eaab9","type":"BoxAnnotation"},"plot":{"id":"a3c97c25-3f6f-42b1-b4e2-5f1768c4740e","subtype":"Figure","type":"Plot"}},"id":"fbce0e97-e76c-48e5-bac1-3370ef64f275","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7bcc0e26-7219-4341-a5c9-4493167f5aaf","type":"Line"},{"attributes":{"base":24,"mantissas":[1,2,4,6,8,12],"max_interval":43200000.0,"min_interval":3600000.0,"num_minor_ticks":0},"id":"9d8cb837-b46e-42f9-ad41-dbe099af761a","type":"AdaptiveTicker"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"ece309fc-1964-4b99-9f11-d93ba3116192","subtype":"Figure","type":"Plot"},"ticker":{"id":"3590982f-49cb-49f6-9240-1b025ec1d09c","type":"DatetimeTicker"}},"id":"7ded3d91-f982-44e9-b89
# ...
